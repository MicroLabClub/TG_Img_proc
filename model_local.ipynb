# %% [markdown]
# **Clasificarea insectelor cu imaginile din dataset**

# %%
from google.colab import drive, files
from google.colab.patches import cv2_imshow
drive.mount('/content/drive/')
dataset_folder = '/content/drive/MyDrive/dataset'
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd
train=pd.read_csv('/content/drive/MyDrive/dataset/train.csv')
train.head()
# Out:
#                                             filename        label
# 0  /kaggle/input/agricultural-pests-image-dataset...        snail
# 1  /kaggle/input/agricultural-pests-image-dataset...         wasp
# 2  /kaggle/input/agricultural-pests-image-dataset...         bees
# 3  /kaggle/input/agricultural-pests-image-dataset...  grasshopper
# 4  /kaggle/input/agricultural-pests-image-dataset...       weevil

# %%
test=pd.read_csv('/content/drive/MyDrive/dataset/test.csv')
test.head()
# Out:
#                                             filename         label
# 0  /kaggle/input/agricultural-pests-image-dataset...          wasp
# 1  /kaggle/input/agricultural-pests-image-dataset...         snail
# 2  /kaggle/input/agricultural-pests-image-dataset...  catterpillar
# 3  /kaggle/input/agricultural-pests-image-dataset...        weevil
# 4  /kaggle/input/agricultural-pests-image-dataset...        beetle

# %%
train['filename']=train['filename'].str.replace('/content/drive/MyDrive/dataset/','/content/drive/MyDrive/dataset/train/')
train.head()
# Out:
#                                             filename        label
# 0  /kaggle/input/agricultural-pests-image-dataset...        snail
# 1  /kaggle/input/agricultural-pests-image-dataset...         wasp
# 2  /kaggle/input/agricultural-pests-image-dataset...         bees
# 3  /kaggle/input/agricultural-pests-image-dataset...  grasshopper
# 4  /kaggle/input/agricultural-pests-image-dataset...       weevil

# %%
test['filename']=test['filename'].str.replace('/content/drive/MyDrive/dataset/','/content/drive/MyDrive/dataset/test/')
test.head()
# Out:
#                                             filename         label
# 0  /kaggle/input/agricultural-pests-image-dataset...          wasp
# 1  /kaggle/input/agricultural-pests-image-dataset...         snail
# 2  /kaggle/input/agricultural-pests-image-dataset...  catterpillar
# 3  /kaggle/input/agricultural-pests-image-dataset...        weevil
# 4  /kaggle/input/agricultural-pests-image-dataset...        beetle

# %%
# !pip install lobe[all]
# Out:
# Collecting lobe[all]
#   Downloading lobe-0.6.2-py3-none-any.whl (22 kB)
# Collecting pillow~=9.0.1 (from lobe[all])
#   Downloading Pillow-9.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from lobe[all]) (2.31.0)
# Collecting matplotlib~=3.5.1 (from lobe[all])
#   Downloading matplotlib-3.5.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 32.9 MB/s eta 0:00:00
# Collecting tensorflow~=2.8.0 (from lobe[all])
#   Downloading tensorflow-2.8.4-cp310-cp310-manylinux2010_x86_64.whl (498.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 498.1/498.1 MB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.5.1->lobe[all]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.5.1->lobe[all]) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.5.1->lobe[all]) (1.4.5)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.5.1->lobe[all]) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.5.1->lobe[all]) (23.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.5.1->lobe[all]) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.5.1->lobe[all]) (2.8.2)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->lobe[all]) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->lobe[all]) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->lobe[all]) (23.5.26)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->lobe[all]) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->lobe[all]) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->lobe[all]) (3.9.0)
# Collecting keras-preprocessing>=1.1.1 (from tensorflow~=2.8.0->lobe[all])
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->lobe[all]) (16.0.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->lobe[all]) (3.3.0)
# Collecting protobuf<3.20,>=3.9.2 (from tensorflow~=2.8.0->lobe[all])
#   Downloading protobuf-3.19.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 67.5 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->lobe[all]) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->lobe[all]) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->lobe[all]) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->lobe[all]) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->lobe[all]) (1.14.1)
# Collecting tensorboard<2.9,>=2.8 (from tensorflow~=2.8.0->lobe[all])
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 88.0 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.9,>=2.8 (from tensorflow~=2.8.0->lobe[all])
#   Downloading tensorflow_estimator-2.8.0-py2.py3-none-any.whl (462 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.3/462.3 kB 45.3 MB/s eta 0:00:00
# Collecting keras<2.9,>=2.8.0rc0 (from tensorflow~=2.8.0->lobe[all])
#   Downloading keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 81.9 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->lobe[all]) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->lobe[all]) (1.60.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->lobe[all]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->lobe[all]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->lobe[all]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->lobe[all]) (2023.11.17)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow~=2.8.0->lobe[all]) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->lobe[all]) (2.17.3)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->lobe[all])
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->lobe[all]) (3.5.1)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->lobe[all])
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 88.0 MB/s eta 0:00:00
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->lobe[all])
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 61.3 MB/s eta 0:00:00
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->lobe[all]) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->lobe[all]) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->lobe[all]) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->lobe[all]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->lobe[all]) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->lobe[all]) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->lobe[all]) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->lobe[all]) (3.2.2)
# Installing collected packages: tensorflow-estimator, tensorboard-plugin-wit, keras, tensorboard-data-server, protobuf, pillow, keras-preprocessing, matplotlib, lobe, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.15.0
#     Uninstalling tensorflow-estimator-2.15.0:
#       Successfully uninstalled tensorflow-estimator-2.15.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.15.0
#     Uninstalling keras-2.15.0:
#       Successfully uninstalled keras-2.15.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.2
#     Uninstalling tensorboard-data-server-0.7.2:
#       Successfully uninstalled tensorboard-data-server-0.7.2
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.2.0
#     Uninstalling google-auth-oauthlib-1.2.0:
#       Successfully uninstalled google-auth-oauthlib-1.2.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.15.1
#     Uninstalling tensorboard-2.15.1:
#       Successfully uninstalled tensorboard-2.15.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.15.0
#     Uninstalling tensorflow-2.15.0:
#       Successfully uninstalled tensorflow-2.15.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# pandas-gbq 0.19.2 requires google-auth-oauthlib>=0.7.0, but you have google-auth-oauthlib 0.4.6 which is incompatible.
# plotnine 0.12.4 requires matplotlib>=3.6.0, but you have matplotlib 3.5.3 which is incompatible.
# tensorflow-datasets 4.9.4 requires protobuf>=3.20, but you have protobuf 3.19.6 which is incompatible.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 3.19.6 which is incompatible.
# Successfully installed google-auth-oauthlib-0.4.6 keras-2.8.0 keras-preprocessing-1.1.2 lobe-0.6.2 matplotlib-3.5.3 pillow-9.0.1 protobuf-3.19.6 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.8.4 tensorflow-estimator-2.8.0

# %%
from lobe import ImageModel

model = ImageModel.load('/content/drive/MyDrive/dataset_res/train TensorFlow')
model

# %%
import os

# the base paths for train and test datasets
base_train_path = '/content/drive/MyDrive/dataset/train'
base_test_path = '/content/drive/MyDrive/dataset/test'

result = []


for filename in test.filename:

    file_path = filename.replace('/kaggle/input/agricultural-pests-image-dataset', base_test_path)

    result_i = model.predict_from_file(file_path)
    result.append(result_i.prediction)

# Display the first five predictions (could do more/less)
result[:5]
# Out:
# ['wasp', 'snail', 'catterpillar', 'weevil', 'beetle']

# %%
test=test.assign(prediction=result)
test.head()
# Out:
#                                             filename         label  \
# 0  /kaggle/input/agricultural-pests-image-dataset...          wasp
# 1  /kaggle/input/agricultural-pests-image-dataset...         snail
# 2  /kaggle/input/agricultural-pests-image-dataset...  catterpillar
# 3  /kaggle/input/agricultural-pests-image-dataset...        weevil
# 4  /kaggle/input/agricultural-pests-image-dataset...        beetle
#
#      prediction
# 0          wasp
# 1         snail
# 2  catterpillar
# 3        weevil
# 4        beetle

# %%
import os

# Specify the base paths for train and test datasets
base_train_path = '/content/drive/MyDrive/dataset/train'
base_test_path = '/content/drive/MyDrive/dataset/test'

result = []  # Initialize an empty list to store predictions

# Iterate through filenames in the 'train' dataset
for filename in train.filename:
    # Replace the Kaggle input path with the local train dataset path
    # Assuming train.filename contains the full path
    file_path = filename.replace('/kaggle/input/agricultural-pests-image-dataset', base_train_path)

    # Predict the class using the trained model for the current file
    result_i = model.predict_from_file(file_path)

    # Append the predicted class to the 'result' list
    result.append(result_i.prediction)

# Display the first five predictions
result[:5]
# Out:
# ['snail', 'wasp', 'bees', 'grasshopper', 'weevil']

# %%
train=train.assign(prediction=result)
train.head()
# Out:
#                                             filename        label   prediction
# 0  /kaggle/input/agricultural-pests-image-dataset...        snail        snail
# 1  /kaggle/input/agricultural-pests-image-dataset...         wasp         wasp
# 2  /kaggle/input/agricultural-pests-image-dataset...         bees         bees
# 3  /kaggle/input/agricultural-pests-image-dataset...  grasshopper  grasshopper
# 4  /kaggle/input/agricultural-pests-image-dataset...       weevil       weevil

# %%
from sklearn.metrics import classification_report
print(classification_report(train['label'],train['prediction']))
# Out:
#               precision    recall  f1-score   support
#
#         ants       0.98      0.97      0.97       400
#         bees       0.97      0.99      0.98       405
#       beetle       0.87      0.94      0.90       331
# catterpillar       0.97      0.93      0.95       329
#   earthworms       0.96      0.98      0.97       246
#       earwig       0.97      0.94      0.95       390
#  grasshopper       0.98      0.97      0.97       390
#         moth       1.00      0.99      0.99       397
#         slug       0.98      0.96      0.97       316
#        snail       1.00      1.00      1.00       405
#         wasp       0.99      0.98      0.99       392
#       weevil       0.98      0.99      0.99       394
#
#     accuracy                           0.97      4395
#    macro avg       0.97      0.97      0.97      4395
# weighted avg       0.97      0.97      0.97      4395

# %%
print(classification_report(test['label'],test['prediction']))
# Out:
#               precision    recall  f1-score   support
#
#         ants       0.91      0.98      0.94        99
#         bees       0.90      0.97      0.93        95
#       beetle       0.57      0.67      0.62        85
# catterpillar       0.80      0.72      0.76       105
#   earthworms       0.82      0.83      0.83        77
#       earwig       0.85      0.74      0.79        76
#  grasshopper       0.89      0.79      0.84        95
#         moth       0.96      0.91      0.93       100
#         slug       0.81      0.81      0.81        75
#        snail       0.96      0.98      0.97        95
#         wasp       0.97      0.96      0.97       106
#       weevil       0.93      0.97      0.95        91
#
#     accuracy                           0.87      1099
#    macro avg       0.86      0.86      0.86      1099
# weighted avg       0.87      0.87      0.87      1099
